# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 10회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 상관계수 절댓값 합 / 표준화(z-score) / 파생 변수 생성
# **제출 방식**: 계산 결과를 `print()` 로 출력
# **주제 데이터**: Breast Cancer (분류 + 통계 가정 점검)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
# > 본 회차 1유형은 **sklearn 원본 BC 데이터(569행)** 를 사용합니다.
#
# ---
#
# ## 데이터 로드 (sklearn 원본)

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
import warnings
warnings.filterwarnings('ignore')

# 10회차 1유형 데이터 — sklearn 원본 (569행 × 31)
bc = load_breast_cancer(as_frame=True).frame
bc.columns = [c.replace(' ', '_') for c in bc.columns]
print(bc.shape)               # (569, 31)
print(bc.columns.tolist())
bc.head()

# %% [markdown]
# ---
#
# ## 문제 10-1-1 (10점) — 상관계수 절댓값의 합
#
# BC 데이터에서 `'mean_'` 으로 시작하는 10개 변수와 `target` 변수 간 **피어슨 상관계수의 절댓값** 을 구하고,
# 그 **합** 을 소수 4자리로 출력하시오.
#
# - `'mean_'` 으로 시작하는 컬럼: `mean_radius, mean_texture, ..., mean_fractal_dimension` (총 10개)
# - 각 변수의 상관계수에 `abs()` 적용 후 `sum()`

# %%
# 여기에 코드를 작성하세요.

답안10_1_1 = None
print(답안10_1_1)

# %% [markdown]
# ---
#
# ## 문제 10-1-2 (10점) — 표준화(Standardization) 후 카운트
#
# BC 데이터의 `mean_radius` 컬럼을 **표준화(평균 0, 표준편차 1)** 한 후,
# 표준화 값(z-score) 이 **1 이상** 인 행의 개수를 정수로 출력하시오.
#
# - z = (x - mean) / std  (pandas `.std()` 는 ddof=1 기본)
# - z ≥ 1 인 행 수를 `int` 로 출력

# %%
# 여기에 코드를 작성하세요.

답안10_1_2 = None
print(답안10_1_2)

# %% [markdown]
# ---
#
# ## 문제 10-1-3 (10점) — 파생 변수 생성 후 평균
#
# BC 데이터에서 `worst_radius` 와 `mean_radius` 를 사용하여
# 새로운 파생 변수 `radius_diff = worst_radius - mean_radius` 를 만들고,
# 이 파생 변수의 **평균** 을 **소수 4자리** 로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

답안10_1_3 = None
print(답안10_1_3)

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - **3문항 합계 30점** 중 **18점 이상** 이면 1유형 합격선입니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Breast Cancer 데이터 기준)*
