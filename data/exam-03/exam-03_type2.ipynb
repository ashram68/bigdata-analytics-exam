# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 3회차
#
# ## 작업형 2유형 · ML 모델링 (1문항 × 40점 = 40점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 회귀 모델 비교 (LinearRegression vs RandomForestRegressor)
# **평가지표**: RMSE, R² (두 모델 각각)
# **목표**: 두 모델 모두 RMSE < 60, R² > 0.40
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
#
# ---
#
# ### ⚠ 시험 환경 안내
#
# - **실제 시험**: 평가용(test) 데이터의 타겟 변수가 주어지지 않음 → 학습 후 예측 결과 CSV 제출.
# - **본 모의고사**: 학습/검증 분할 후 RMSE·R² 를 직접 출력하는 형태로 단순화.
#
# ---
#
# ## 데이터 로드

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes
import warnings
warnings.filterwarnings('ignore')

# 3회차 공통 데이터 — sklearn 내장 Diabetes (442명, 10 변수 + target)
df = load_diabetes(as_frame=True).frame
print(df.shape)              # (442, 11)
print(df.columns.tolist())   # ['age', 'sex', 'bmi', 'bp', 's1'~'s6', 'target']
df.head()

# %% [markdown]
# ---
#
# ## 문제 3-2 (40점) — Diabetes 회귀: LinearRegression vs RandomForestRegressor
#
# Diabetes 데이터의 **모든 변수(10개)** 를 사용하여 `target` 값을 예측하는 두 회귀 모델을 학습하고,
# 검증 데이터에 대한 **RMSE 와 R²** 를 각각 출력한 뒤 어느 모델이 더 우수한지 비교하시오.
#
# ### 수행 순서
# 1. X = 10개 변수, y = target
# 2. `train_test_split(test_size=0.2, random_state=42)`
# 3. 모델 1: `LinearRegression()` 학습
# 4. 모델 2: `RandomForestRegressor(n_estimators=100, random_state=42)` 학습
# 5. 두 모델의 검증 RMSE, R² 각각 출력
# 6. RandomForest 의 `feature_importances_` 상위 3개 출력
#
# ### 출력 형식
# ```
# LR  -> RMSE: ____, R²: ____
# RF  -> RMSE: ____, R²: ____
# Top-3 features: [____, ____, ____]
# ```
#
# ### 목표
# - 두 모델 모두 **RMSE < 60**, **R² > 0.40**

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - 풀이를 마쳤다면 모의고사 사이트로 돌아가 **[정답 및 해설 보기]** 를 클릭하세요.
# - **모델 선택 가이드**:
#   - LinearRegression 이 유리: 변수와 타겟 사이 선형 관계가 강할 때 / 표본이 작을 때 / 회귀계수 해석이 중요할 때
#   - RandomForest 가 유리: 비선형 관계 / 변수 간 상호작용 / 변수 중요도 필요 / 이상치 강건성
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Diabetes 데이터 기준)*
