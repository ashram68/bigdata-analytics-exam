# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 3회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 데이터 전처리, 이상값 탐지, 그룹 평균 비교, 분위수 필터링
# **제출 방식**: 계산 결과를 `print()` 로 출력
# **주제 데이터**: Diabetes (당뇨 진행도, sklearn 내장)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
# > `random_state` 는 모두 `42` 로 통일합니다.
#
# ---
#
# ## 데이터 로드
#
# 본 회차의 모든 문제는 `sklearn` 내장 **Diabetes** 데이터셋(442명 × 11컬럼)을 사용합니다.
# 모든 입력 변수(10개)는 평균 0, L2 norm = 1 로 사전 정규화되어 있으며, `target` 은 1년 후 당뇨 진행도(원본 값)입니다.

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes
import warnings
warnings.filterwarnings('ignore')

# 3회차 공통 데이터 — sklearn 내장 Diabetes (442명, 10 변수 + target)
df = load_diabetes(as_frame=True).frame
print(df.shape)              # (442, 11)
print(df.columns.tolist())   # ['age', 'sex', 'bmi', 'bp', 's1'~'s6', 'target']
df.head()

# %% [markdown]
# ---
#
# ## 문제 3-1-1 (10점) — target 변수의 z-score 이상값 행 카운트
#
# `target` 변수를 표준화(z-score)하였을 때, **|z| > 1.96** 에 해당하는 이상값(outlier) 행의 수를
# 정수로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 3-1-2 (10점) — sex 그룹별 target 평균 차이
#
# `sex` 변수의 두 그룹(이 데이터에서 sex 는 -0.0446, 0.0507 두 값만 가짐) 의
# **target 평균 차이의 절댓값** 을 **소수 둘째 자리** 까지 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 3-1-3 (10점) — bp 상위 25% 그룹의 target 평균
#
# `bp`(혈압) **상위 25% 임계값(75% 분위수)** 이상인 환자들의 **target 평균** 을
# **정수로 반올림** 하여 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - 풀이를 마쳤다면 모의고사 사이트로 돌아가 **[정답 및 해설 보기]** 를 클릭하세요.
# - **3문항 합계 30점** 중 **18점 이상** 이면 1유형 합격선입니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Diabetes 데이터 기준)*
