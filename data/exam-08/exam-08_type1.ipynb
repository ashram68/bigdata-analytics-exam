# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 8회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 이상치 탐지(z-score) / 결측치 비율 / 그룹 비교
# **제출 방식**: 계산 결과를 `print()` 로 출력
# **주제 데이터**: Diabetes 분류 변환 (sklearn diabetes 의 target 을 중앙값 기준 이진화)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
# > 본 회차 1유형은 **학습용 데이터(train.csv)** 를 사용합니다 (일부 컬럼에 결측치 사전 주입).
#
# ---
#
# ## 데이터 로드 (train.csv)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# 8회차 1유형 데이터 — 사이트 호스팅 train.csv (353행 × 12, ID + 10변수 + high_target)
BASE = 'https://raw.githubusercontent.com/ashram68/bigdata-analytics-exam/main/data/exam-08/'
data = pd.read_csv(BASE + 'train.csv')
print(data.shape)             # (353, 12)
print(data.isnull().sum())    # age, bmi, s3 에 결측치 존재
data.head()

# %% [markdown]
# ---
#
# ## 문제 8-1-1 (10점) — 이상치(z-score) 탐지
#
# `train.csv` 의 `bmi` 컬럼에 대해 z-score 를 계산하고,
# **|z| > 1.96** 조건을 만족하는 이상치 행의 개수를 정수로 출력하시오. (결측치는 z-score 계산에서 자동 제외됨)
#
# - 평균(μ) 과 표본 표준편차(σ, ddof=1) 는 결측치 제외 기본값으로 계산
# - z = (x - μ) / σ
# - |z| > 1.96 인 행 수를 정수로 출력

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 8-1-2 (10점) — 결측치 비율(%) 계산
#
# `train.csv` 의 `bmi` 컬럼의 **결측치 비율(%)** 을 계산하고
# 소수 둘째 자리로 반올림하여 출력하시오.
#
# - 결측 비율 = (bmi 결측 개수 / 전체 행 수) × 100
# - `round(x, 2)` 로 반올림

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 8-1-3 (10점) — 노인층(age ≥ 평균) 의 high_target 비율
#
# `train.csv` 에서 `age` 결측치를 **age 의 중앙값** 으로 대체한 후,
# age 가 **전체 평균 이상** 인 환자들 중 `high_target=1` 의 비율을 **소수 4자리** 로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - **3문항 합계 30점** 중 **18점 이상** 이면 1유형 합격선입니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Diabetes 분류 변환 데이터 기준)*
