# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 4회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: IQR 이상값, 그룹 비교, 상관계수 합
# **제출 방식**: 계산 결과를 `print()` 로 출력
# **주제 데이터**: Diabetes (당뇨 진행도, sklearn 내장 — 3회차와 동일)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
#
# ---
#
# ## 데이터 로드

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes
import warnings
warnings.filterwarnings('ignore')

# 4회차 공통 데이터 — sklearn 내장 Diabetes (3회차와 동일, 442명 × 11)
df = load_diabetes(as_frame=True).frame
print(df.shape)              # (442, 11)
print(df.columns.tolist())
df.head()

# %% [markdown]
# ---
#
# ## 문제 4-1-1 (10점) — bmi 변수의 IQR 기반 이상값 행 카운트
#
# `bmi` 변수의 IQR(Interquartile Range) 을 계산하여,
# **Q1 - 1.5×IQR** 미만 또는 **Q3 + 1.5×IQR** 초과에 해당하는 이상값 행의 수를
# 정수로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 4-1-2 (10점) — target 평균 기준 이분화 → bp 평균 차이
#
# `target` 변수의 **평균값** 을 기준으로 데이터를 두 그룹(평균 이상 = high, 평균 미만 = low) 으로 나누고,
# 각 그룹의 `bp` 평균 차이의 **절댓값** 을 **소수 넷째 자리** 까지 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 4-1-3 (10점) — 입력변수와 target 의 상관계수 절댓값 합
#
# 10개 입력변수(age, sex, bmi, bp, s1~s6) 각각과 `target` 사이의 **Pearson 상관계수** 를 구한 뒤,
# **절댓값을 모두 합한 값** 을 **소수 둘째 자리** 까지 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - **3문항 합계 30점** 중 **18점 이상** 이면 1유형 합격선입니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Diabetes 데이터 기준)*
