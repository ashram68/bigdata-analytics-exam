# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 4회차
#
# ## 작업형 2유형 · ML 모델링 (1문항 × 40점 = 40점)
#
# **출제 범위**: 회귀 모델 3종 비교 (LinearRegression vs RandomForest vs GradientBoosting)
# **평가지표**: RMSE, R²
# **목표**: 세 모델 모두 RMSE < 60, R² > 0.40
#
# ---
#
# ## 데이터 로드

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes
import warnings
warnings.filterwarnings('ignore')

# 4회차 공통 데이터 — sklearn 내장 Diabetes (3회차와 동일, 442명 × 11)
df = load_diabetes(as_frame=True).frame
print(df.shape)              # (442, 11)
print(df.columns.tolist())
df.head()

# %% [markdown]
# ---
#
# ## 문제 4-2 (40점) — Diabetes 회귀: LR vs RF vs GBR 3-모델 비교
#
# Diabetes 데이터의 모든 변수(10개) 를 사용하여 `target` 값을 예측하는 **세 회귀 모델** 을 학습하고,
# 검증 데이터에 대한 **RMSE 와 R²** 를 각각 출력한 뒤 어느 모델이 가장 우수한지 결정하시오.
#
# ### 수행 순서
# 1. X = 10개 변수, y = target
# 2. `train_test_split(test_size=0.2, random_state=42)`
# 3. 모델 1: `LinearRegression()`
# 4. 모델 2: `RandomForestRegressor(n_estimators=100, random_state=42)`
# 5. 모델 3: `GradientBoostingRegressor(n_estimators=100, random_state=42)`
# 6. 세 모델의 RMSE, R² 출력 + RMSE 기준 최고 모델 선언
# 7. RandomForest 의 `feature_importances_` Top-3
#
# ### 출력 형식
# ```
# LR  -> RMSE: ____, R²: ____
# RF  -> RMSE: ____, R²: ____
# GBR -> RMSE: ____, R²: ____
# Best model: ____
# Top-3 features: [____, ____, ____]
# ```

# %%
# 여기에 코드를 작성하세요.

# from sklearn.linear_model import LinearRegression
# from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error, r2_score
# import numpy as np

# X, y 분리, train_test_split
# 3개 모델 학습 + RMSE/R² 출력
# Best model 선언
# Top-3 features 출력

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - **3개 모델 학습 메커니즘 차이**:
#   - LR: 최소제곱법으로 한 번에 해 추정 → 빠르고 해석 쉬움, 선형 관계 가정
#   - RF: 다수의 의사결정나무 독립 학습 후 평균 → 비선형 OK, bagging, overfitting 강함
#   - GBR: 이전 나무의 잔차를 다음 나무가 학습 → 비선형 + 부스팅, 일반적으로 RF 보다 정확
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Diabetes 데이터 기준)*
