# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 5회차
#
# ## 작업형 2유형 · ML 모델링 (1문항 × 40점 = 40점)
#
# **출제 범위**: 이진 분류 (Breast Cancer 양성/악성)
# **평가지표**: ROC-AUC
# **목표**: AUC ≥ 0.95 (이 데이터는 분리력이 매우 좋음)
#
# ---
#
# ## 데이터 로드

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
import warnings
warnings.filterwarnings('ignore')

# 5회차 공통 데이터 — sklearn 내장 Breast Cancer (569명 × 31)
bc = load_breast_cancer(as_frame=True).frame
bc.columns = [c.replace(' ', '_') for c in bc.columns]
print(bc.shape)              # (569, 31)
print(bc['target'].value_counts())
bc.head()

# %% [markdown]
# ---
#
# ## 문제 5-2 (40점) — 유방암 양성/악성 이진 분류
#
# Breast Cancer 데이터를 사용하여 **양성/악성 이진 분류** 모델을 학습하고,
# 검증 데이터에 대한 **ROC-AUC** 를 출력하시오.
#
# ### 수행 순서
# 1. X = 30개 특성, y = `target`
# 2. `train_test_split(test_size=0.2, random_state=42, stratify=y)`
# 3. `RandomForestClassifier(n_estimators=100, random_state=42)` 학습
# 4. `predict_proba` 로 양성 클래스(target=1) 확률 추출 → `roc_auc_score`
#
# ### 출력 형식
# ```
# AUC: ____
# ```
#
# ### 사용 가능 모델
# RandomForest, XGBoost, LogisticRegression 등 자유 (본 해설은 RandomForest 기준)

# %%
# 여기에 코드를 작성하세요.

# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import roc_auc_score

# X, y 분리 → train_test_split (stratify=y)
# RandomForestClassifier 학습 → predict_proba 로 양성 확률
# roc_auc_score 계산 + 출력

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - 본 데이터는 30개 진단 변수의 분리력이 매우 좋아 AUC 99% 수준이 일반적입니다.
# - **임상 실무 주의**: AUC 99% 모델이라도 의료에서는 false negative(악성을 양성으로 오진) 가 치명적이므로,
#   recall(민감도) 최대화를 위해 임계값(threshold) 을 0.5 보다 낮게 조정하는 전략을 자주 사용합니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Breast Cancer 데이터 기준)*
