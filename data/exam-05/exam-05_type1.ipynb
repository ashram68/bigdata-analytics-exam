# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 5회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 평균 이상 카운트, 그룹 평균 차이, 분위수 기반 조건 카운트
# **제출 방식**: 계산 결과를 `print()` 로 출력
# **주제 데이터**: Breast Cancer (유방암 진단, sklearn 내장)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
#
# ---
#
# ## 데이터 로드

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
import warnings
warnings.filterwarnings('ignore')

# 5회차 공통 데이터 — sklearn 내장 Breast Cancer (569명 × 31)
bc = load_breast_cancer(as_frame=True).frame
# 컬럼명 공백을 underscore 로 변환 (예: 'mean radius' → 'mean_radius')
bc.columns = [c.replace(' ', '_') for c in bc.columns]
print(bc.shape)              # (569, 31)
print(bc['target'].value_counts())
# 1 (benign): 357
# 0 (malignant): 212
bc.head()

# %% [markdown]
# ---
#
# ## 문제 5-1-1 (10점) — mean_radius 평균 이상 카운트
#
# Breast Cancer 데이터에서 `mean_radius` 가 **전체 평균 이상** 인 환자의 수를 정수로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 5-1-2 (10점) — 양성 - 악성 mean_area 차이
#
# `target` 별 `mean_area` 의 평균을 구하고,
# **(양성 평균) - (악성 평균)** 을 정수로 변환(버림) 하여 출력하시오.
#
# > `target`: 0 = 악성(malignant), 1 = 양성(benign)

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 5-1-3 (10점) — worst_radius 상위 20% 양성 환자 수
#
# `worst_radius` 상위 20% 임계값 (80% 분위수) **이상** 인 환자들 중
# **양성(target=1)** 인 환자의 수를 정수로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - **3문항 합계 30점** 중 **18점 이상** 이면 1유형 합격선입니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Breast Cancer 데이터 기준)*
