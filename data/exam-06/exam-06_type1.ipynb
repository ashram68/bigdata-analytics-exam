# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 6회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 결측치 처리 / 파생 변수(family) / 그룹별 비교
# **제출 방식**: 계산 결과를 `print()` 로 출력
# **주제 데이터**: Titanic (Kaggle CSV, 다른 변수 활용)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
# > 본 회차는 **외부 CSV 파일** (`titanic.csv`) 를 사용하며, 컬럼명은 Kaggle 원본 PascalCase 그대로 사용 (Survived, Pclass, Gender, Age, SibSp, Parch, Fare, Embarked).
#
# ---
#
# ## 데이터 로드 (titanic.csv)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# 6회차 데이터 — 사이트 호스팅 titanic.csv (891행 × 12, Kaggle 원본 PascalCase)
BASE = 'https://raw.githubusercontent.com/ashram68/bigdata-analytics-exam/main/data/exam-06/'
df = pd.read_csv(BASE + 'titanic.csv')
print(df.shape)               # (891, 12)
print(df.columns.tolist())
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender',
#  'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
df.head()

# %% [markdown]
# ---
#
# ## 문제 6-1-1 (10점) — Embarked 결측 처리 후 C 항구 카운트
#
# Titanic 데이터에서 `Embarked` 변수의 결측치를 **최빈값으로 대체** 한 후,
# **C(Cherbourg) 항구** 에서 탑승한 승객 수를 정수로 출력하시오.
#
# > 💡 **힌트**: `df['Embarked'].mode()[0]` 으로 최빈값을 구하고 `fillna()` 로 대체. Embarked 결측은 2건 뿐.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 6-1-2 (10점) — 가족 있는 승객 생존율
#
# **가족크기 = SibSp + Parch** 가 0보다 큰 승객의 **생존율** 을 **소수 4자리** 로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 6-1-3 (10점) — Pclass 별 생존율 차이 (max - min)
#
# `Pclass` (객실 등급) 별 **생존율** 을 구하고,
# **최댓값과 최솟값의 차이** 를 **소수 4자리** 로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - **3문항 합계 30점** 중 **18점 이상** 이면 1유형 합격선입니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (Kaggle Titanic 데이터 기준)*
