# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 2회차
#
# ## 작업형 2유형 · ML 모델링 (1문항 × 40점 = 40점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 다중 클래스 분류 (RandomForest 등)
# **평가지표**: Accuracy (목표 ≥ 0.85)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
# > `random_state` 는 모두 `42` 로 통일합니다.
#
# ---
#
# ### ⚠ 시험 환경 핵심 안내
#
# - **실제 시험**: 평가용(test) 데이터의 타겟 변수가 주어지지 **않음**.
#   학습용 데이터로 모델 학습 → 평가용 데이터에 대한 예측 결과를 CSV 로 제출 → 시스템 자동 채점.
# - **본 모의고사 플랫폼**: 학습/검증 분할 후 **검증 정확도** 를 직접 출력하는 형태로 단순화.
#
# ---
#
# ## 데이터 로드

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
import warnings
warnings.filterwarnings('ignore')

# 2회차 공통 데이터 — sklearn 내장 Iris (5컬럼 표준 구조)
iris = load_iris(as_frame=True).frame
iris.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target']
iris['species'] = iris['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
iris = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']]

print(iris.shape)              # (150, 5)
print(iris['species'].value_counts())
iris.head()

# %% [markdown]
# ---
#
# ## 문제 2-2 (40점) — Iris 다중 클래스 분류
#
# Iris 데이터를 **3개 클래스(setosa / versicolor / virginica)** 로 분류하는 모델을 학습시키고,
# **검증 데이터에 대한 정확도(accuracy)** 를 출력하시오.
#
# ### 수행 순서
# 1. 4개 변수 사용: `sepal_length`, `sepal_width`, `petal_length`, `petal_width`
# 2. 타겟 변수: `species` (문자열) → `LabelEncoder` 또는 `map()` 으로 정수 인코딩
# 3. `train_test_split(test_size=0.2, random_state=42, stratify=y)`
# 4. `RandomForestClassifier(n_estimators=100, random_state=42)`
# 5. 검증 데이터 정확도 출력
#
# ### 목표
# - **accuracy ≥ 0.85**

# %%
# 여기에 코드를 작성하세요.

# %%
# (자가채점) 검증 데이터 정확도 출력 — 실제 시험에서는 출력 불필요
# acc = rf.score(X_va, y_va)
# print(f'Accuracy: {acc:.4f}')   # 0.9000

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - 풀이를 마쳤다면 모의고사 사이트로 돌아가 **[정답 및 해설 보기]** 를 클릭하세요.
# - **2유형 합격선**: Accuracy ≥ 0.85
# - **다중 분류 평가지표 옵션 정리** (시험 빈출):
#   - `accuracy_score`: 옵션 불필요
#   - `f1_score`, `precision_score`, `recall_score`: `average='macro'/'weighted'/'micro'` **必**
#   - `roc_auc_score`: `multi_class='ovr'/'ovo'` + `average='macro'` **必**
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Iris 데이터 기준)*
