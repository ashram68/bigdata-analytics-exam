# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 1회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 데이터 전처리
# **제출 방식**: 계산 결과를 `print()` 로 출력
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
# > 외부 사이트 검색 없이 `help(함수명)` 만 사용하여 풀이하세요.
#
# ---
#
# ## 데이터 로드

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Titanic 데이터셋 (1회차 공통 데이터)
df = pd.read_csv('https://raw.githubusercontent.com/ashram68/bigdata-analytics-exam/main/data/exam-01/titanic_1.csv')
df.head()

# %% [markdown]
# ---
#
# ## 문제 1 (10점)
#
# Titanic 데이터에서 **Age 변수의 결측치를 Age의 중위수(median)로 대체**한 후,
# **생존자(Survived = 1) 의 평균 나이**를 구하시오.
#
# (단, 결과는 **소수 둘째 자리까지 반올림**하여 출력)
#
# **제출 변수**: `답안1` 에 결과를 저장하고 `print(답안1)` 로 출력하세요.

# %%
# 여기에 코드를 작성하세요.

답안1 = None  # ← 결과 변수에 저장
print(답안1)

# %% [markdown]
# ---
#
# ## 문제 2 (10점)
#
# *원고 도착 후 활성화됩니다.*

# %%
# 준비 중

# %% [markdown]
# ---
#
# ## 문제 3 (10점)
#
# *원고 도착 후 활성화됩니다.*

# %%
# 준비 중

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - 풀이를 마쳤다면 모의고사 사이트로 돌아가 **[정답 및 해설 보기]** 를 클릭하세요.
# - 자가채점은 1·3유형은 `print()` 출력 결과 비교, 2유형은 평가지표 기준으로 진행합니다.
# - 60점 이상이면 합격선입니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기*
