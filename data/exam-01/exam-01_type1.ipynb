# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 1회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 데이터 전처리, 결측치 처리, 그룹 집계, 분위수 필터링
# **제출 방식**: 계산 결과를 `print()` 로 출력 (정수 답안은 `int()` 변환 필수)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
# > 외부 사이트 검색 없이 `help(함수명)` 만 사용하여 풀이하세요.
# > `random_state` 는 모두 `42` 로 통일합니다.
#
# ---
#
# ## 데이터 로드
#
# 본 회차의 모든 문제는 `seaborn` 내장 **Titanic** 데이터셋(891행 × 15열)을 사용합니다.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# 1회차 공통 데이터 (라이브러리 내장 데이터셋 — 외부 fetch 불필요)
df = sns.load_dataset('titanic')

print(df.shape)              # (891, 15)
print(df.isnull().sum())     # 결측치: age(177), embarked(2), deck(688)
df.head()

# %% [markdown]
# ---
#
# ## 문제 1-1 (10점) — 결측치 처리와 조건부 카운트
#
# 주어진 Titanic 데이터에서 `age` 컬럼의 결측치를 `age` 컬럼의 **중앙값**으로 대체한 후,
# **나이가 30세 이상**인 승객의 수를 **정수형(int)** 으로 출력하시오.
#
# > 💡 정수 답안 출력 시 반드시 `int()` 또는 `round()` 로 변환하세요.
# > `(df['age'] >= 30).sum()` 은 `numpy.int64` 를 반환하므로 명시적 변환을 권장합니다.

# %%
# 여기에 코드를 작성하세요.

답안1_1 = None  # ← 결과를 정수로 저장
print(답안1_1)

# %% [markdown]
# ---
#
# ## 문제 1-2 (10점) — 그룹 집계 및 차이 계산
#
# Titanic 데이터에서 `pclass` 별 `fare`(요금)의 **평균**을 구한 뒤,
# `(1등석의 평균 fare) - (3등석의 평균 fare)` 의 차이를 계산하고,
# 이 값을 **버림**하여 정수로 출력하시오.
#
# > 💡 버림 처리는 `int()` 또는 `numpy.floor()` 를 사용합니다.
# > 음수에서 동작이 다르니 주의 — 본 문제는 양수이므로 `int()` 로 충분합니다.

# %%
# 여기에 코드를 작성하세요.

답안1_2 = None  # ← 결과를 정수로 저장
print(답안1_2)

# %% [markdown]
# ---
#
# ## 문제 1-3 (10점) — 분위수 기반 필터링과 합계
#
# Titanic 데이터에서 `fare`(요금)의 **상위 10% 임계값**(즉, **90% 분위수**)을 계산한 후,
# `fare` 가 그 임계값 **이상**인 승객들 중 **생존자(survived = 1)** 의 수를 정수로 출력하시오.
#
# > 💡 90% 분위수는 `df['fare'].quantile(0.9)` 로 구할 수 있습니다.
# > 다중 조건 필터링은 `df[(조건1) & (조건2)]` 또는 단계별 필터링 모두 가능합니다.

# %%
# 여기에 코드를 작성하세요.

답안1_3 = None  # ← 결과를 정수로 저장
print(답안1_3)

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - 풀이를 마쳤다면 모의고사 사이트로 돌아가 **[정답 및 해설 보기]** 를 클릭하세요.
# - 자가채점은 `print()` 출력 결과를 정답과 직접 비교하면 됩니다.
# - **3문항 합계 30점** 중 **18점 이상** 이면 1유형 합격선입니다.
# - 이어서 **2유형(40점) / 3유형(30점)** 도 풀이해 주세요.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (seaborn Titanic 데이터 기준, Kaggle Titanic 데이터셋 참고)*
