# %% [markdown]
# # 빅데이터 분석기사 실기 모의고사 9회차
#
# ## 작업형 1유형 · 데이터 전처리 (3문항 × 10점 = 30점)
#
# **제한 시간**: 180분 (전체 1·2·3유형 합산)
# **합격선**: 60점 / 100점
# **출제 범위**: 다중 조건 카운트 / 분위수 기반 필터링 / 집단 평균 차이
# **제출 방식**: 계산 결과를 `print()` 로 출력
# **주제 데이터**: Wine (alcohol 회귀 예측)
#
# > 본 모의고사는 **폐쇄형 시험 환경**을 가정합니다.
# > 본 회차 1유형은 **학습용 데이터(train.csv)** 를 사용합니다.
#
# ---
#
# ## 데이터 로드 (train.csv)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# 9회차 1유형 데이터 — 사이트 호스팅 train.csv (142행 × 14, ID + 12변수 + alcohol)
BASE = 'https://raw.githubusercontent.com/ashram68/bigdata-analytics-exam/main/data/exam-09/'
train = pd.read_csv(BASE + 'train.csv')
print(train.shape)            # (142, 14)
print(train.columns.tolist())
train.head()

# %% [markdown]
# ---
#
# ## 문제 9-1-1 (10점) — 다중 조건 카운트
#
# `train.csv` 에서 `alcohol` 이 **13 이상** 이면서 `color_intensity` 가 **5 이상** 인 와인의 개수를 정수로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 9-1-2 (10점) — 상위 분위수 추출 후 평균
#
# `train.csv` 에서 `proline` 이 **상위 10% 임계값(90% 분위수) 이상** 인 와인들의
# `alcohol` 평균을 **소수 4자리** 로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 문제 9-1-3 (10점) — 집단 간 평균 차이의 절댓값
#
# `train.csv` 에서 `color_intensity` 의 **중앙값** 을 기준으로 두 그룹(high/low) 으로 나눈 후,
# 두 그룹 사이의 `alcohol` 평균 차이의 **절댓값** 을 **소수 4자리** 로 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
#
# ## 풀이 종료 안내
#
# - **3문항 합계 30점** 중 **18점 이상** 이면 1유형 합격선입니다.
#
# ---
#
# *폐쇄형 시험 환경 적응 모의고사 - 빅데이터 분석기사 실기 (sklearn Wine 회귀 변환 데이터 기준)*
